# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/AIA_Project/blob/main/AIA_Project_Meta_model_approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Meta Model approach

# %%
# !pip install rasterio
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.1.4)

# %%
# !pip install shap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from sklearn import tree
import shap

import matplotlib.pyplot as plt

import rasterio
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import recall_score

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier


from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.ensemble import StackingRegressor

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit

from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from subprocess import check_output


from sklearn.inspection import permutation_importance
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline



import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/PhD_Main_Folder/Courses/Advanced_Image_Analysis/AIA_Project_Folder
# /content/drive/MyDrive/sample_partition
# !ls
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /content/drive/MyDrive/PhD_Main_Folder/Courses/Advanced_Image_Analysis/AIA_Project_Folder
#  10_14_Project_Concept_Presentation.gslides  'Project Concept.gdoc'     Wheat_training.csv
#  AIA_Project_workflow.gdraw		      Project_Timeline.gsheet   Wheat_validation.csv
#  Final_Presentation.gslides		      stackedResampled.tif
#  LandsatComposite_2022.tif		      Wheat_testing.csv

# %%
train=pd.read_csv("Wheat_training.csv")
print("Train dataset has {} samples and {} attributes".format(*train.shape))

train_copy = train.copy()
train_copy
# Out:
# Train dataset has 3000 samples and 37 attributes
#       system:index  MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS  \
# 0                0  -0.548781 -0.452262 -0.128196 -0.276454  0.128196
# 1                1  -0.503139 -0.473595  0.234021  0.208830 -0.234021
# 2                2  -0.462866 -0.387527  0.061947 -0.003232 -0.061947
# 3                3  -0.484955 -0.498822 -0.234642 -0.083216  0.234642
# 4                4  -0.416667 -0.487419  0.067681  0.156486 -0.067681
# ...            ...        ...       ...       ...       ...       ...
# 2995          2995  -0.504221 -0.480650  0.127613  0.156394 -0.127613
# 2996          2996  -0.504555 -0.515298  0.078694  0.049212 -0.078694
# 2997          2997  -0.477100 -0.463863  0.078837  0.025603 -0.078837
# 2998          2998  -0.520775 -0.498801  0.061755  0.011967 -0.061755
# 2999          2999  -0.496867 -0.469319  0.176541  0.088005 -0.176541
#
#        NDMI_LS  NDWI_HLS   NDWI_LS    S2_EVI  ...  greenness  ndratio_A  \
# 0     0.276454 -0.632481 -0.647737  0.409796  ...   0.143628  -0.199905
# 1    -0.208830 -0.305035 -0.293792  0.146633  ...  -0.012620  -0.216282
# 2     0.003232 -0.412754 -0.390271  0.172569  ...   0.071336  -0.282255
# 3     0.083216 -0.646080 -0.559367  0.211860  ...   0.096046  -0.158692
# 4    -0.156486 -0.359112 -0.358214  0.202313  ...   0.013699  -0.169358
# ...        ...       ...       ...       ...  ...        ...        ...
# 2995 -0.156394 -0.402508 -0.350599  0.111636  ...   0.021298  -0.238970
# 2996 -0.049212 -0.443470 -0.478193  0.197364  ...   0.045889  -0.145954
# 2997 -0.025603 -0.413829 -0.443526  0.226138  ...   0.037233  -0.208332
# 2998 -0.011967 -0.474273 -0.489745  0.265219  ...   0.050898  -0.229408
# 2999 -0.088005 -0.351126 -0.397742  0.170675  ...   0.027715  -0.244782
#
#       ndratio_D    random   ratio_A   ratio_D     sixth     slope   wetness  \
# 0     -0.186033  0.532955  0.666799  0.686293 -0.021866  1.517278 -0.062167
# 1     -0.182059  0.453445  0.644356  0.691963 -0.034136  7.257873 -0.191377
# 2     -0.285364  0.432256  0.559752  0.555980 -0.020837  0.705395 -0.118801
# 3     -0.214673  0.694207  0.726084  0.646533 -0.023128  1.263989 -0.045594
# 4     -0.181266  0.152050  0.710340  0.693099 -0.027884  1.533710 -0.174224
# ...         ...       ...       ...       ...       ...       ...       ...
# 2995  -0.194921  0.248483  0.614245  0.673751 -0.031419  0.717514 -0.192628
# 2996  -0.137202  0.048150  0.745270  0.758703 -0.029875  0.942266 -0.150554
# 2997  -0.177493  0.445189  0.655174  0.698524 -0.028049  1.215313 -0.135881
# 2998  -0.261282  0.213424  0.626800  0.585688 -0.024553  0.759658 -0.119146
# 2999  -0.300828  0.526998  0.606707  0.537482 -0.032081  1.479565 -0.155585
#
#                                                    .geo
# 0     {"geodesic":false,"type":"Point","coordinates"...
# 1     {"geodesic":false,"type":"Point","coordinates"...
# 2     {"geodesic":false,"type":"Point","coordinates"...
# 3     {"geodesic":false,"type":"Point","coordinates"...
# 4     {"geodesic":false,"type":"Point","coordinates"...
# ...                                                 ...
# 2995  {"geodesic":false,"type":"Point","coordinates"...
# 2996  {"geodesic":false,"type":"Point","coordinates"...
# 2997  {"geodesic":false,"type":"Point","coordinates"...
# 2998  {"geodesic":false,"type":"Point","coordinates"...
# 2999  {"geodesic":false,"type":"Point","coordinates"...
#
# [3000 rows x 37 columns]

# %%
test=pd.read_csv("Wheat_testing.csv")
print("Test dataset has {} samples and {} attributes".format(*test.shape))

print("cropland")
sns.histplot(test,x="cropland")

test["cropland"].describe()

test_copy = test.copy()
# Out:
# Test dataset has 3000 samples and 37 attributes
# cropland

# %%
validation=pd.read_csv("Wheat_validation.csv")
print("validation dataset has {} samples and {} attributes".format(*validation.shape))

print("cropland")
sns.histplot(validation,x="cropland")

validation["cropland"].describe()

validation_copy = validation.copy()
validation_copy
# Out:
# validation dataset has 3000 samples and 37 attributes
# cropland
#       system:index  MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS  \
# 0                0  -0.474083 -0.431388  0.180589  0.120619 -0.180589
# 1                1  -0.501734 -0.440518  0.148345  0.096441 -0.148345
# 2                2  -0.502738 -0.489296  0.212134  0.188685 -0.212134
# 3                3  -0.535002 -0.412594 -0.118922 -0.124632  0.118922
# 4                4  -0.470089 -0.445818  0.148587  0.093806 -0.148587
# ...            ...        ...       ...       ...       ...       ...
# 2995          2995  -0.507679 -0.497766  0.138907  0.088678 -0.138907
# 2996          2996  -0.493146 -0.508966  0.104807  0.102806 -0.104807
# 2997          2997  -0.511582 -0.506763  0.170387  0.040370 -0.170387
# 2998          2998  -0.514226 -0.517805  0.157688  0.148403 -0.157688
# 2999          2999  -0.485027 -0.498396  0.110113  0.128292 -0.110113
#
#        NDMI_LS  NDWI_HLS   NDWI_LS    S2_EVI  ...  greenness  ndratio_A  \
# 0    -0.120619 -0.320975 -0.327870  0.147228  ...   0.002978  -0.194046
# 1    -0.096441 -0.381807 -0.359344  0.166386  ...   0.005452  -0.247962
# 2    -0.188685 -0.325295 -0.331188  0.135224  ...  -0.002271  -0.315483
# 3     0.124632 -0.614808 -0.510915  0.216502  ...   0.126135  -0.228498
# 4    -0.093806 -0.345645 -0.367347  0.149002  ...   0.013308  -0.194996
# ...        ...       ...       ...       ...  ...        ...        ...
# 2995 -0.088678 -0.396752 -0.427982  0.140406  ...   0.038924  -0.293866
# 2996 -0.102806 -0.409504 -0.428586  0.183548  ...   0.035839  -0.240093
# 2997 -0.040370 -0.373776 -0.476134  0.294284  ...   0.011508  -0.260907
# 2998 -0.148403 -0.388000 -0.400164  0.256382  ...   0.016743  -0.351970
# 2999 -0.128292 -0.396068 -0.395379  0.154017  ...   0.023706  -0.243476
#
#       ndratio_D    random   ratio_A   ratio_D     sixth     slope   wetness  \
# 0     -0.228888  0.797169  0.674977  0.627487 -0.033028  3.124353 -0.195240
# 1     -0.260684  0.406833  0.602613  0.586440 -0.028940  0.236278 -0.160197
# 2     -0.296442  0.928373  0.520354  0.542683 -0.031689  0.616255 -0.222351
# 3     -0.235494  0.862856  0.628004  0.618786 -0.013582  1.750103 -0.062381
# 4     -0.193764  0.288302  0.673646  0.675373 -0.031262  1.444699 -0.148671
# ...         ...       ...       ...       ...       ...       ...       ...
# 2995  -0.294088  0.585181  0.545755  0.545489 -0.030150  0.813987 -0.168166
# 2996  -0.199761  0.040135  0.612782  0.666998 -0.029621  0.180154 -0.144997
# 2997  -0.349500  0.860333  0.586159  0.482031 -0.027317  0.915927 -0.141277
# 2998  -0.370623  0.108302  0.479323  0.459191 -0.031224  0.571081 -0.142797
# 2999  -0.248805  0.994338  0.608394  0.601531 -0.030120  0.374026 -0.165106
#
#                                                    .geo
# 0     {"geodesic":false,"type":"Point","coordinates"...
# 1     {"geodesic":false,"type":"Point","coordinates"...
# 2     {"geodesic":false,"type":"Point","coordinates"...
# 3     {"geodesic":false,"type":"Point","coordinates"...
# 4     {"geodesic":false,"type":"Point","coordinates"...
# ...                                                 ...
# 2995  {"geodesic":false,"type":"Point","coordinates"...
# 2996  {"geodesic":false,"type":"Point","coordinates"...
# 2997  {"geodesic":false,"type":"Point","coordinates"...
# 2998  {"geodesic":false,"type":"Point","coordinates"...
# 2999  {"geodesic":false,"type":"Point","coordinates"...
#
# [3000 rows x 37 columns]

# %% [markdown]
# # Data handeling

# %% [markdown]
# train

# %%
y_train=pd.DataFrame(train_copy['cropland'])
y_train
# Out:
#       cropland
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2995         1
# 2996         1
# 2997         1
# 2998         1
# 2999         1
#
# [3000 rows x 1 columns]

# %%
train_copy.drop(['system:index', 'cropland', 'random', '.geo'], axis=1, inplace=True)
x_train = train_copy
x_train
# Out:
#       MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS   NDMI_LS  NDWI_HLS  \
# 0     -0.548781 -0.452262 -0.128196 -0.276454  0.128196  0.276454 -0.632481
# 1     -0.503139 -0.473595  0.234021  0.208830 -0.234021 -0.208830 -0.305035
# 2     -0.462866 -0.387527  0.061947 -0.003232 -0.061947  0.003232 -0.412754
# 3     -0.484955 -0.498822 -0.234642 -0.083216  0.234642  0.083216 -0.646080
# 4     -0.416667 -0.487419  0.067681  0.156486 -0.067681 -0.156486 -0.359112
# ...         ...       ...       ...       ...       ...       ...       ...
# 2995  -0.504221 -0.480650  0.127613  0.156394 -0.127613 -0.156394 -0.402508
# 2996  -0.504555 -0.515298  0.078694  0.049212 -0.078694 -0.049212 -0.443470
# 2997  -0.477100 -0.463863  0.078837  0.025603 -0.078837 -0.025603 -0.413829
# 2998  -0.520775 -0.498801  0.061755  0.011967 -0.061755 -0.011967 -0.474273
# 2999  -0.496867 -0.469319  0.176541  0.088005 -0.176541 -0.088005 -0.351126
#
#        NDWI_LS    S2_EVI  S2_MNDWI  ...     fifth    fourth  greenness  \
# 0    -0.647737  0.409796 -0.232677  ...  0.068213 -0.053244   0.143628
# 1    -0.293792  0.146633 -0.321927  ...  0.085853 -0.055893  -0.012620
# 2    -0.390271  0.172569 -0.273393  ...  0.110723 -0.037847   0.071336
# 3    -0.559367  0.211860 -0.244325  ...  0.036143 -0.046307   0.096046
# 4    -0.358214  0.202313 -0.281426  ...  0.100798 -0.050824   0.013699
# ...        ...       ...       ...  ...       ...       ...        ...
# 2995 -0.350599  0.111636 -0.253410  ...  0.103979 -0.058381   0.021298
# 2996 -0.478193  0.197364 -0.282324  ...  0.086303 -0.052748   0.045889
# 2997 -0.443526  0.226138 -0.290802  ...  0.081933 -0.047192   0.037233
# 2998 -0.489745  0.265219 -0.247799  ...  0.075657 -0.052030   0.050898
# 2999 -0.397742  0.170675 -0.309303  ...  0.093271 -0.053208   0.027715
#
#       ndratio_A  ndratio_D   ratio_A   ratio_D     sixth     slope   wetness
# 0     -0.199905  -0.186033  0.666799  0.686293 -0.021866  1.517278 -0.062167
# 1     -0.216282  -0.182059  0.644356  0.691963 -0.034136  7.257873 -0.191377
# 2     -0.282255  -0.285364  0.559752  0.555980 -0.020837  0.705395 -0.118801
# 3     -0.158692  -0.214673  0.726084  0.646533 -0.023128  1.263989 -0.045594
# 4     -0.169358  -0.181266  0.710340  0.693099 -0.027884  1.533710 -0.174224
# ...         ...        ...       ...       ...       ...       ...       ...
# 2995  -0.238970  -0.194921  0.614245  0.673751 -0.031419  0.717514 -0.192628
# 2996  -0.145954  -0.137202  0.745270  0.758703 -0.029875  0.942266 -0.150554
# 2997  -0.208332  -0.177493  0.655174  0.698524 -0.028049  1.215313 -0.135881
# 2998  -0.229408  -0.261282  0.626800  0.585688 -0.024553  0.759658 -0.119146
# 2999  -0.244782  -0.300828  0.606707  0.537482 -0.032081  1.479565 -0.155585
#
# [3000 rows x 33 columns]

# %% [markdown]
# test

# %%
y_test=pd.DataFrame(test_copy['cropland'])
y_test
# Out:
#       cropland
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2995         1
# 2996         1
# 2997         1
# 2998         1
# 2999         1
#
# [3000 rows x 1 columns]

# %%
test_copy.drop(['system:index', 'cropland', 'random', '.geo'], axis=1, inplace=True)
x_test = test_copy
x_test
# Out:
#       MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS   NDMI_LS  NDWI_HLS  \
# 0     -0.542359 -0.530312  0.222850  0.194206 -0.222850 -0.194206 -0.363436
# 1     -0.470342 -0.444007  0.162397  0.136558 -0.162397 -0.136558 -0.333411
# 2     -0.433494 -0.354463 -0.095567 -0.048894  0.095567  0.048894 -0.508015
# 3     -0.452239 -0.411715 -0.024887  0.005404  0.024887 -0.005404 -0.471816
# 4     -0.453676 -0.431740  0.187900  0.173294 -0.187900 -0.173294 -0.290544
# ...         ...       ...       ...       ...       ...       ...       ...
# 2995  -0.447197 -0.461341  0.102439  0.078814 -0.102439 -0.078814 -0.361310
# 2996  -0.501368 -0.461251  0.108376  0.036634 -0.108376 -0.036634 -0.415573
# 2997  -0.498204 -0.494806  0.112731  0.065607 -0.112731 -0.065607 -0.408411
# 2998  -0.541937 -0.447535  0.154580 -0.010454 -0.154580  0.010454 -0.422774
# 2999  -0.502458 -0.490053  0.153404  0.081272 -0.153404 -0.081272 -0.378205
#
#        NDWI_LS    S2_EVI  S2_MNDWI  ...     fifth    fourth  greenness  \
# 0    -0.374684  0.155687 -0.340521  ...  0.061955 -0.045112   0.008674
# 1    -0.327293  0.148807 -0.244876  ...  0.114054 -0.054281   0.006585
# 2    -0.396486  0.164972 -0.198032  ...  0.088687 -0.045139   0.104623
# 3    -0.407217  0.245060 -0.192085  ...  0.082210 -0.051142   0.061674
# 4    -0.279971  0.130897 -0.261543  ...  0.081541 -0.055197  -0.013551
# ...        ...       ...       ...  ...       ...       ...        ...
# 2995 -0.396940  0.194497 -0.287929  ...  0.093813 -0.055520   0.021340
# 2996 -0.431915  0.230115 -0.269097  ...  0.075146 -0.043476   0.030401
# 2997 -0.443611  0.256431 -0.224464  ...  0.089159 -0.055645   0.022275
# 2998 -0.455892  0.347730 -0.273250  ...  0.079762 -0.054519   0.020969
# 2999 -0.424109  0.210272 -0.253223  ...  0.105155 -0.058109   0.018067
#
#       ndratio_A  ndratio_D   ratio_A   ratio_D     sixth     slope   wetness
# 0     -0.204363  -0.165000  0.660629  0.716738 -0.031580  2.016724 -0.187081
# 1     -0.243747  -0.245895  0.608044  0.605271 -0.033288  0.569219 -0.192053
# 2     -0.243126  -0.254618  0.608848  0.594111 -0.028868  1.074596 -0.096737
# 3     -0.280835  -0.302363  0.561481  0.535670 -0.021832  1.287155 -0.107916
# 4     -0.254457  -0.229490  0.594316  0.626690 -0.036808  4.249340 -0.172420
# ...         ...        ...       ...       ...       ...       ...       ...
# 2995  -0.175812  -0.197851  0.700952  0.669657 -0.038304  1.409270 -0.148781
# 2996  -0.182737  -0.176984  0.690993  0.699258 -0.024739  0.230132 -0.143740
# 2997  -0.324413  -0.225344  0.510102  0.632195 -0.029031  0.329136 -0.144309
# 2998  -0.208111  -0.217813  0.655477  0.642288 -0.027585  1.636277 -0.151386
# 2999  -0.268630  -0.280767  0.576504  0.561564 -0.027625  0.515526 -0.177949
#
# [3000 rows x 33 columns]

# %%
y_validation = pd.DataFrame(validation_copy['cropland'])
y_validation
# Out:
#       cropland
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2995         1
# 2996         1
# 2997         1
# 2998         1
# 2999         1
#
# [3000 rows x 1 columns]

# %%
validation_copy.drop(['system:index', 'cropland', 'random', '.geo'], axis=1, inplace=True)
x_validation = validation_copy
x_validation
# Out:
#       MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS   NDMI_LS  NDWI_HLS  \
# 0     -0.474083 -0.431388  0.180589  0.120619 -0.180589 -0.120619 -0.320975
# 1     -0.501734 -0.440518  0.148345  0.096441 -0.148345 -0.096441 -0.381807
# 2     -0.502738 -0.489296  0.212134  0.188685 -0.212134 -0.188685 -0.325295
# 3     -0.535002 -0.412594 -0.118922 -0.124632  0.118922  0.124632 -0.614808
# 4     -0.470089 -0.445818  0.148587  0.093806 -0.148587 -0.093806 -0.345645
# ...         ...       ...       ...       ...       ...       ...       ...
# 2995  -0.507679 -0.497766  0.138907  0.088678 -0.138907 -0.088678 -0.396752
# 2996  -0.493146 -0.508966  0.104807  0.102806 -0.104807 -0.102806 -0.409504
# 2997  -0.511582 -0.506763  0.170387  0.040370 -0.170387 -0.040370 -0.373776
# 2998  -0.514226 -0.517805  0.157688  0.148403 -0.157688 -0.148403 -0.388000
# 2999  -0.485027 -0.498396  0.110113  0.128292 -0.110113 -0.128292 -0.396068
#
#        NDWI_LS    S2_EVI  S2_MNDWI  ...     fifth    fourth  greenness  \
# 0    -0.327870  0.147228 -0.309908  ...  0.103328 -0.051410   0.002978
# 1    -0.359344  0.166386 -0.307576  ...  0.096526 -0.053621   0.005452
# 2    -0.331188  0.135224 -0.322681  ...  0.112189 -0.058573  -0.002271
# 3    -0.510915  0.216502 -0.216340  ...  0.067953 -0.040987   0.126135
# 4    -0.367347  0.149002 -0.289384  ...  0.081696 -0.054155   0.013308
# ...        ...       ...       ...  ...       ...       ...        ...
# 2995 -0.427982  0.140406 -0.249289  ...  0.093513 -0.056062   0.038924
# 2996 -0.428586  0.183548 -0.272669  ...  0.090033 -0.054205   0.035839
# 2997 -0.476134  0.294284 -0.304751  ...  0.070995 -0.048854   0.011508
# 2998 -0.400164  0.256382 -0.305571  ...  0.068753 -0.050985   0.016743
# 2999 -0.395379  0.154017 -0.292154  ...  0.093251 -0.054606   0.023706
#
#       ndratio_A  ndratio_D   ratio_A   ratio_D     sixth     slope   wetness
# 0     -0.194046  -0.228888  0.674977  0.627487 -0.033028  3.124353 -0.195240
# 1     -0.247962  -0.260684  0.602613  0.586440 -0.028940  0.236278 -0.160197
# 2     -0.315483  -0.296442  0.520354  0.542683 -0.031689  0.616255 -0.222351
# 3     -0.228498  -0.235494  0.628004  0.618786 -0.013582  1.750103 -0.062381
# 4     -0.194996  -0.193764  0.673646  0.675373 -0.031262  1.444699 -0.148671
# ...         ...        ...       ...       ...       ...       ...       ...
# 2995  -0.293866  -0.294088  0.545755  0.545489 -0.030150  0.813987 -0.168166
# 2996  -0.240093  -0.199761  0.612782  0.666998 -0.029621  0.180154 -0.144997
# 2997  -0.260907  -0.349500  0.586159  0.482031 -0.027317  0.915927 -0.141277
# 2998  -0.351970  -0.370623  0.479323  0.459191 -0.031224  0.571081 -0.142797
# 2999  -0.243476  -0.248805  0.608394  0.601531 -0.030120  0.374026 -0.165106
#
# [3000 rows x 33 columns]

# %%
# # Example: If you have a DataFrame 'df' with 'rh100' as the target column.
# def plot_scatter_with_cropland(x_train, target_column='cropland'):
#     # Check if 'rh100' exists in the DataFrame
#     if target_column not in train.columns:
#         raise ValueError(f"'{target_column}' is not a column in the DataFrame.")

#     # Set up the number of subplots based on the number of columns (excluding 'rh100')
#     features = train.drop(columns=[target_column]).columns
#     num_cols = len(features)
#     num_rows = (num_cols // 3) + 1  # Customize for more/less features per row

#     fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))  # Adjust figure size
#     axes = axes.flatten()  # Flatten the axes array for easy indexing

#     for i, column in enumerate(features):
#         sns.scatterplot(x=train[column], y=train[target_column], ax=axes[i])
#         axes[i].set_title(f"{column} vs {target_column}")
#         axes[i].set_xlabel(column)
#         axes[i].set_ylabel(target_column)

#     # Remove any unused subplots
#     for j in range(i + 1, len(axes)):
#         fig.delaxes(axes[j])

#     plt.tight_layout()
#     plt.show()

# # Example: df = pd.read_csv('your_dataset.csv')
# plot_scatter_with_cropland(train)

# %%
head_list = list(x_train.columns.values)
head_list
# Out:
# ['MNDWI_HLS',
#  'MNDWI_LS',
#  'NDBI_HLS',
#  'NDBI_LS',
#  'NDMI_HLS',
#  'NDMI_LS',
#  'NDWI_HLS',
#  'NDWI_LS',
#  'S2_EVI',
#  'S2_MNDWI',
#  'S2_NDBI',
#  'S2_NDMI',
#  'S2_NDVI',
#  'S2_NDWI',
#  'S2_SAVI',
#  'SAVI_HLS',
#  'SAVI_LS',
#  'VH_A',
#  'VH_D',
#  'VV_A',
#  'VV_D',
#  'brightness',
#  'dem',
#  'fifth',
#  'fourth',
#  'greenness',
#  'ndratio_A',
#  'ndratio_D',
#  'ratio_A',
#  'ratio_D',
#  'sixth',
#  'slope',
#  'wetness']

# %%
corr_df=train[head_list]  #New dataframe to calculate correlation between numeric features
cor= corr_df.corr(method='pearson')
print(cor)
# Out:
#             MNDWI_HLS  MNDWI_LS  NDBI_HLS   NDBI_LS  NDMI_HLS   NDMI_LS  \
# MNDWI_HLS    1.000000  0.733047 -0.333574 -0.161364  0.333574  0.161364
# MNDWI_LS     0.733047  1.000000 -0.354466 -0.294459  0.354466  0.294459
# NDBI_HLS    -0.333574 -0.354466  1.000000  0.826873 -1.000000 -0.826873
# NDBI_LS     -0.161364 -0.294459  0.826873  1.000000 -0.826873 -1.000000
# NDMI_HLS     0.333574  0.354466 -1.000000 -0.826873  1.000000  0.826873
# NDMI_LS      0.161364  0.294459 -0.826873 -1.000000  0.826873  1.000000
# NDWI_HLS     0.322092  0.137893  0.782564  0.730236 -0.782564 -0.730236
# NDWI_LS      0.339956  0.392279  0.559489  0.762334 -0.559489 -0.762334
# S2_EVI      -0.212495 -0.191188 -0.465160 -0.635852  0.465160  0.635852
# S2_MNDWI     0.410262  0.413467 -0.667982 -0.580209  0.667982  0.580209
# S2_NDBI     -0.094540 -0.133714  0.793771  0.854428 -0.793771 -0.854428
# S2_NDMI      0.094540  0.133714 -0.793771 -0.854428  0.793771  0.854428
# S2_NDVI     -0.274688 -0.246206 -0.425980 -0.613910  0.425980  0.613910
# S2_NDWI      0.264385  0.210481  0.490016  0.659276 -0.490016 -0.659276
# S2_SAVI     -0.224996 -0.192384 -0.488163 -0.662144  0.488163  0.662144
# SAVI_HLS    -0.132935 -0.011417 -0.865839 -0.777256  0.865839  0.777256
# SAVI_LS     -0.218076 -0.239483 -0.626613 -0.835633  0.626613  0.835633
# VH_A         0.174250  0.156793 -0.392062 -0.358060  0.392062  0.358060
# VH_D         0.219829  0.226519 -0.364511 -0.322358  0.364511  0.322358
# VV_A         0.228259  0.229680 -0.278244 -0.204246  0.278244  0.204246
# VV_D         0.248628  0.248149 -0.255898 -0.198151  0.255898  0.198151
# brightness   0.525726  0.470638  0.007189  0.148544 -0.007189 -0.148544
# dem          0.068517 -0.016534  0.117101  0.105482 -0.117101 -0.105482
# fifth        0.439638  0.307874  0.067872  0.146328 -0.067872 -0.146328
# fourth      -0.249799 -0.085747 -0.157030 -0.126796  0.157030  0.126796
# greenness   -0.119711 -0.006925 -0.835147 -0.792310  0.835147  0.792310
# ndratio_A   -0.165015 -0.174099  0.093385  0.028696 -0.093385 -0.028696
# ndratio_D   -0.187311 -0.182889  0.129005  0.082859 -0.129005 -0.082859
# ratio_A     -0.166046 -0.176067  0.103201  0.037670 -0.103201 -0.037670
# ratio_D     -0.196109 -0.191812  0.141427  0.092721 -0.141427 -0.092721
# sixth       -0.509104 -0.387504 -0.333409 -0.338497  0.333409  0.338497
# slope        0.083275  0.081161  0.226756  0.255943 -0.226756 -0.255943
# wetness      0.126755  0.234128 -0.791208 -0.770307  0.791208  0.770307
#
#             NDWI_HLS   NDWI_LS    S2_EVI  S2_MNDWI  ...     fifth    fourth  \
# MNDWI_HLS   0.322092  0.339956 -0.212495  0.410262  ...  0.439638 -0.249799
# MNDWI_LS    0.137893  0.392279 -0.191188  0.413467  ...  0.307874 -0.085747
# NDBI_HLS    0.782564  0.559489 -0.465160 -0.667982  ...  0.067872 -0.157030
# NDBI_LS     0.730236  0.762334 -0.635852 -0.580209  ...  0.146328 -0.126796
# NDMI_HLS   -0.782564 -0.559489  0.465160  0.667982  ... -0.067872  0.157030
# NDMI_LS    -0.730236 -0.762334  0.635852  0.580209  ... -0.146328  0.126796
# NDWI_HLS    1.000000  0.800804 -0.620313 -0.401025  ...  0.359620 -0.326536
# NDWI_LS     0.800804  1.000000 -0.741336 -0.281558  ...  0.350445 -0.186425
# S2_EVI     -0.620313 -0.741336  1.000000  0.153343  ... -0.301119  0.175473
# S2_MNDWI   -0.401025 -0.281558  0.153343  1.000000  ...  0.166526 -0.130899
# S2_NDBI     0.745012  0.735167 -0.745359 -0.714899  ...  0.102091 -0.094932
# S2_NDMI    -0.745012 -0.735167  0.745359  0.714899  ... -0.102091  0.094932
# S2_NDVI    -0.623342 -0.757950  0.981024  0.047007  ... -0.369789  0.225142
# S2_NDWI     0.680477  0.779309 -0.914669 -0.053053  ...  0.308623 -0.265963
# S2_SAVI    -0.652000 -0.768012  0.987232  0.124299  ... -0.312043  0.209379
# SAVI_HLS   -0.954177 -0.757950  0.585529  0.467793  ... -0.240674  0.214657
# SAVI_LS    -0.784299 -0.964617  0.737135  0.331595  ... -0.265677  0.127314
# VH_A       -0.278444 -0.239501  0.266661  0.373266  ... -0.161614  0.008522
# VH_D       -0.221028 -0.160185  0.178610  0.423862  ... -0.120452 -0.040562
# VV_A       -0.127658 -0.044681  0.041463  0.360007  ...  0.144540 -0.060199
# VV_D       -0.092434 -0.027340  0.033938  0.341393  ...  0.187915 -0.097734
# brightness  0.358600  0.461441 -0.395968  0.117955  ...  0.813644 -0.329232
# dem         0.166948  0.094222 -0.015165  0.183507  ...  0.074144 -0.165111
# fifth       0.359620  0.350445 -0.301119  0.166526  ...  1.000000 -0.671562
# fourth     -0.326536 -0.186425  0.175473 -0.130899  ... -0.671562  1.000000
# greenness  -0.917016 -0.771084  0.583089  0.474041  ... -0.274617  0.302958
# ndratio_A  -0.016497 -0.086959  0.101978 -0.196449  ... -0.229969  0.072904
# ndratio_D   0.005296 -0.040128  0.041465 -0.201994  ... -0.243384  0.091968
# ratio_A    -0.006956 -0.079313  0.096689 -0.207361  ... -0.235592  0.071151
# ratio_D     0.012124 -0.036466  0.037410 -0.214863  ... -0.253623  0.093166
# sixth      -0.672968 -0.593489  0.402860  0.150553  ... -0.326004  0.391812
# slope       0.291456  0.307101 -0.217970 -0.191552  ... -0.137591  0.016433
# wetness    -0.713139 -0.586172  0.525382  0.494979  ... -0.549468  0.397611
#
#             greenness  ndratio_A  ndratio_D   ratio_A   ratio_D     sixth  \
# MNDWI_HLS   -0.119711  -0.165015  -0.187311 -0.166046 -0.196109 -0.509104
# MNDWI_LS    -0.006925  -0.174099  -0.182889 -0.176067 -0.191812 -0.387504
# NDBI_HLS    -0.835147   0.093385   0.129005  0.103201  0.141427 -0.333409
# NDBI_LS     -0.792310   0.028696   0.082859  0.037670  0.092721 -0.338497
# NDMI_HLS     0.835147  -0.093385  -0.129005 -0.103201 -0.141427  0.333409
# NDMI_LS      0.792310  -0.028696  -0.082859 -0.037670 -0.092721  0.338497
# NDWI_HLS    -0.917016  -0.016497   0.005296 -0.006956  0.012124 -0.672968
# NDWI_LS     -0.771084  -0.086959  -0.040128 -0.079313 -0.036466 -0.593489
# S2_EVI       0.583089   0.101978   0.041465  0.096689  0.037410  0.402860
# S2_MNDWI     0.474041  -0.196449  -0.201994 -0.207361 -0.214863  0.150553
# S2_NDBI     -0.766518   0.083309   0.132293  0.095934  0.144337 -0.429022
# S2_NDMI      0.766518  -0.083309  -0.132293 -0.095934 -0.144337  0.429022
# S2_NDVI      0.570395   0.124646   0.057369  0.120136  0.054998  0.425272
# S2_NDWI     -0.640300  -0.071287  -0.006519 -0.063790 -0.001741 -0.471717
# S2_SAVI      0.616001   0.097743   0.031438  0.091770  0.027300  0.428044
# SAVI_HLS     0.935877   0.022054  -0.002642  0.012915 -0.010709  0.528598
# SAVI_LS      0.794499   0.097165   0.043992  0.089516  0.038838  0.484919
# VH_A         0.274168  -0.017268  -0.155961  0.002414 -0.148838  0.125186
# VH_D         0.219129  -0.212719  -0.179371 -0.198494 -0.164785  0.084876
# VV_A         0.137419  -0.888028  -0.711431 -0.888530 -0.718017  0.109681
# VV_D         0.106387  -0.704391  -0.934529 -0.709514 -0.940497  0.074008
# brightness  -0.207287  -0.167418  -0.162873 -0.171778 -0.172234 -0.457689
# dem         -0.171923   0.008335  -0.026834  0.011659 -0.026915 -0.084223
# fifth       -0.274617  -0.229969  -0.243384 -0.235592 -0.253623 -0.326004
# fourth       0.302958   0.072904   0.091968  0.071151  0.093166  0.391812
# greenness    1.000000   0.003827  -0.020050 -0.006741 -0.029264  0.610332
# ndratio_A    0.003827   1.000000   0.721797  0.994923  0.719455 -0.046037
# ndratio_D   -0.020050   0.721797   1.000000  0.720178  0.994752 -0.042591
# ratio_A     -0.006741   0.994923   0.720178  1.000000  0.724904 -0.054789
# ratio_D     -0.029264   0.719455   0.994752  0.724904  1.000000 -0.045857
# sixth        0.610332  -0.046037  -0.042591 -0.054789 -0.045857  1.000000
# slope       -0.274973   0.139836   0.132777  0.145623  0.136761 -0.264400
# wetness      0.743049   0.030255  -0.004260  0.025843 -0.009520  0.374748
#
#                slope   wetness
# MNDWI_HLS   0.083275  0.126755
# MNDWI_LS    0.081161  0.234128
# NDBI_HLS    0.226756 -0.791208
# NDBI_LS     0.255943 -0.770307
# NDMI_HLS   -0.226756  0.791208
# NDMI_LS    -0.255943  0.770307
# NDWI_HLS    0.291456 -0.713139
# NDWI_LS     0.307101 -0.586172
# S2_EVI     -0.217970  0.525382
# S2_MNDWI   -0.191552  0.494979
# S2_NDBI     0.323885 -0.708226
# S2_NDMI    -0.323885  0.708226
# S2_NDVI    -0.213089  0.530917
# S2_NDWI     0.277438 -0.533989
# S2_SAVI    -0.239461  0.547176
# SAVI_HLS   -0.266225  0.712085
# SAVI_LS    -0.291566  0.601752
# VH_A       -0.037351  0.468416
# VH_D       -0.013544  0.428266
# VV_A       -0.153130  0.191529
# VV_D       -0.128340  0.157143
# brightness -0.031961 -0.475185
# dem         0.047100 -0.058856
# fifth      -0.137591 -0.549468
# fourth      0.016433  0.397611
# greenness  -0.274973  0.743049
# ndratio_A   0.139836  0.030255
# ndratio_D   0.132777 -0.004260
# ratio_A     0.145623  0.025843
# ratio_D     0.136761 -0.009520
# sixth      -0.264400  0.374748
# slope       1.000000 -0.087183
# wetness    -0.087183  1.000000
#
# [33 rows x 33 columns]

# %%
fig, ax =plt.subplots(figsize=(10, 10))
plt.title("Correlation Plot")
sns.heatmap(cor, mask=np.zeros_like(cor), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %%
fig, ax=plt.subplots(1,figsize=(8,6))
sns.boxplot(x='cropland',y='S2_NDVI', data=train)
ax.set_ylim(0,.5)
plt.title("S2_NDVI vs cropland")
plt.show()

# %% [markdown]
# ## Tif

# %%
# Replace 'your_image.tif' with the actual file name of the uploaded .tif image
image_path = 'stack_resample.tif'

# Load the .tif image using rasterio
with rasterio.open(image_path) as src:
    image = src.read()  # Read all the bands of the image

# Check the dimensions of the image (bands, height, width)
print(image.shape)

# Reshape the image so that each pixel is a sample (for input into scikit-learn)
image_reshaped = image.reshape(image.shape[0], -1).T  # Shape will be (num_pixels, num_bands)
print("Reshaped image shape:", image_reshaped.shape)

# %%
# Single-band image (e.g., grayscale or elevation data)
plt.figure(figsize=(8, 8))
plt.imshow(image[0], cmap='gray')  # Assuming it's a single-band image, use 'image[0]' to access the first band
plt.title('Single-band .tif Image')
plt.colorbar()
plt.show()

# %%
# Create some sample training labels (for simplicity, we manually define some points)
# For real-world applications, this part should involve actual labeled data

# Example: First 100 pixels are class 0 (e.g., water), next 100 pixels are class 1 (e.g., vegetation)
# The size of labeled_data and labels should match the real data you use.
labeled_data = image_reshaped[:200, :]  # Example labeled data (you need real labeled regions)
labels = np.array([0] * 100 + [1] * 100)  # Example labels: 0 for first 100 pixels, 1 for next 100

# %%
# Standardize the full image data (using the same scaler fitted on the training data)
image_scaled = scaler.transform(image_reshaped)

# Predict the class of each pixel in the entire image
predicted_labels = svm_model.predict(image_scaled)

# Reshape the predicted labels back to the original image shape (height, width)
predicted_image = predicted_labels.reshape(image.shape[1], image.shape[2])

print("Prediction complete. Shape of predicted image:", predicted_image.shape)

# %% [markdown]
# # Grid Search params and data scaling

# %%
###scale data for algorithms that need it
sc = StandardScaler()
x_train_sc = pd.DataFrame(sc.fit_transform(x_train))
x_test_sc = pd.DataFrame(sc.transform(x_test))

# %%
##used for the MLP
scaler = MinMaxScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.fit_transform(x_test)

# %%
folds  = 5
score_calc = 'accuracy' #'neg_mean_squared_error'

# %%
# def get_best_score(grid):

#     best_score = np.sqrt(-grid.best_score_)
#     print(best_score)
#     print(grid.best_params_)
#     print(grid.best_estimator_)

#     return best_score

# %%
def get_best_score(grid):

    best_score = grid.best_score_
    print(best_score)
    print(grid.best_params_)
    print(grid.best_estimator_)

    return best_score

# %% [markdown]
# ## SVM Classificaiton

# %%
param_grid = {'C': [10],'coef0': [0.01], 'degree': [3], 'gamma': [0.1], 'kernel': ['linear']}

# param_grid = {'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
#               'C' : [0.1, 1, 10],
#               'degree' : [3],
#               'coef0' : [0.01,10],
#               'gamma' : [0.1, 0.01, 0.001]}

grid_svc = GridSearchCV(SVC(), param_grid, cv = folds, refit = True, verbose = 3, scoring = score_calc)
grid_svc.fit(x_train_sc.values, y_train["cropland"].values)

sc_svc = get_best_score(grid_svc)

pred_svc = grid_svc.predict(x_test_sc.values)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=linear;, score=0.913 total time=   2.3s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=linear;, score=0.920 total time=   4.3s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=linear;, score=0.890 total time=   1.5s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=linear;, score=0.897 total time=   1.0s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=linear;, score=0.888 total time=   1.2s
# 0.9016666666666667
# {'C': 10, 'coef0': 0.01, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# SVC(C=10, coef0=0.01, gamma=0.1, kernel='linear')

# %%
print('F1-Score:', f1_score(y_test, pred_svc))
print('Recall:', recall_score(y_test, pred_svc))
print('Accuracy:',accuracy_score(y_test, pred_svc))
print('Precision:',precision_score(y_test, pred_svc))
print('classification_report',classification_report(y_test, pred_svc))
cm = confusion_matrix(y_test, pred_svc)
cm
# Out:
# F1-Score: 0.8992758393680053
# Recall: 0.9106666666666666
# Accuracy: 0.898
# Precision: 0.8881664499349805
# classification_report               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      1500
#            1       0.89      0.91      0.90      1500
#
#     accuracy                           0.90      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.90      0.90      0.90      3000
# array([[1328,  172],
#        [ 134, 1366]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= [0, 1])
disp.plot()

plt.show()

# %%
best_model = grid_svc.best_estimator_

coefficients = np.abs(best_model.coef_).flatten()

# Create a DataFrame to display feature importance
feature_importance = pd.DataFrame({'Feature': x_train.columns.values, 'Importance': coefficients})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

# Display the most important features
print(feature_importance)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance['Feature'], feature_importance['Importance'], color='lightcoral')
plt.gca().invert_yaxis()
plt.xlabel('Importance')
plt.title('Feature Importance from GridSearchCV Optimized Linear SVM')
# Out:
#        Feature  Importance
# 6     NDWI_HLS    6.399159
# 13     S2_NDWI    5.463355
# 0    MNDWI_HLS    5.075919
# 7      NDWI_LS    4.829957
# 2     NDBI_HLS    4.029512
# 4     NDMI_HLS    4.029512
# 12     S2_NDVI    4.029415
# 9     S2_MNDWI    3.935410
# 10     S2_NDBI    3.909432
# 11     S2_NDMI    3.909432
# 1     MNDWI_LS    3.865468
# 3      NDBI_LS    3.096519
# 5      NDMI_LS    3.096519
# 16     SAVI_LS    2.959477
# 8       S2_EVI    2.205963
# 19        VV_A    1.319023
# 15    SAVI_HLS    1.266188
# 28     ratio_A    1.043594
# 27   ndratio_D    1.029809
# 17        VH_A    1.000749
# 20        VV_D    0.871431
# 25   greenness    0.832957
# 23       fifth    0.648516
# 26   ndratio_A    0.542463
# 21  brightness    0.508184
# 24      fourth    0.398651
# 30       sixth    0.374332
# 14     S2_SAVI    0.344761
# 32     wetness    0.305732
# 31       slope    0.254974
# 22         dem    0.165116
# 29     ratio_D    0.061789
# 18        VH_D    0.060515
# Text(0.5, 1.0, 'Feature Importance from GridSearchCV Optimized Linear SVM')

# %%
# Standardize the features
scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# Classify the entire image
image_scaled = scaler.transform(image)
predicted_labels = svm.predict(image_scaled)

# Reshape the predicted labels back to the original image shape
predicted_labels_image = predicted_labels.reshape((height, width))

# Optionally save the classified image using rasterio
with rasterio.open('classified_image.tif', 'w', driver='GTiff',
                   height=height, width=width, count=1, dtype=predicted_labels_image.dtype) as dst:
    dst.write(predicted_labels_image, 1)

# %%
# Plot original, ground truth, and classified images
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(labels.reshape((height, width)), cmap='tab20b')
plt.title('Ground Truth')
plt.subplot(1, 2, 2)
plt.imshow(predicted_labels_image, cmap='tab20b')
plt.title('Classified Image')
plt.show()

# %% [markdown]
# ## RF Classifer

# %%
param_grid = {'min_samples_split' : [3], 'n_estimators' : [150], 'random_state': [5]}

# param_grid = {
#               'n_estimators': [10,50,100,150,200],
#               'criterion': ['gini', 'entropy', 'log_loss'],
#               'n_estimators': [50, 60, 70, 100, 150],
#               'max_depth':  [None, 2,4,6,8],
#               'max_features': ['sqrt', 'log2', None],
#               'min_samples_split': [2,4,6,8],
#               'random_state': [42]}


grid_rf = GridSearchCV(RandomForestClassifier(), param_grid, cv = folds, refit=True, verbose = 3, scoring = score_calc)
grid_rf.fit(x_train.values, y_train['cropland'].values)

sc_rf = get_best_score(grid_rf)
pred_rf = grid_rf.predict(x_test.values)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.918 total time=   2.7s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.910 total time=   2.4s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.903 total time=   2.0s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.922 total time=   2.0s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.897 total time=   2.0s
# 0.9099999999999999
# {'min_samples_split': 3, 'n_estimators': 150, 'random_state': 5}
# RandomForestClassifier(min_samples_split=3, n_estimators=150, random_state=5)

# %%
print('F1-Score:', f1_score(y_test, pred_rf))
print('Recall:', recall_score(y_test, pred_rf))
print('Accuracy:',accuracy_score(y_test, pred_rf))
print('Precision:',precision_score(y_test, pred_rf))
print('classification_report',classification_report(y_test, pred_rf))
cm = confusion_matrix(y_test, pred_rf)
cm
# Out:
# F1-Score: 0.9077637690776377
# Recall: 0.912
# Accuracy: 0.9073333333333333
# Precision: 0.9035667107001321
# classification_report               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      1500
#            1       0.90      0.91      0.91      1500
#
#     accuracy                           0.91      3000
#    macro avg       0.91      0.91      0.91      3000
# weighted avg       0.91      0.91      0.91      3000
# array([[1354,  146],
#        [ 132, 1368]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= [0, 1])
disp.plot()

plt.show()

# %%
best_model = grid_rf.best_estimator_

# Get feature importance from the best model
feature_importance = best_model.feature_importances_

# Create a DataFrame to display feature importance
feature_importance_df = pd.DataFrame({'Feature': x_train.columns.values, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the most important features
print(feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='lightcoral')
plt.gca().invert_yaxis()
plt.xlabel('Importance')
plt.title('Feature Importance from GridSearchCV Optimized XGBoost')
plt.show()
# Out:
#        Feature  Importance
# 16     SAVI_LS    0.117578
# 11     S2_NDMI    0.092300
# 10     S2_NDBI    0.078264
# 14     S2_SAVI    0.067677
# 8       S2_EVI    0.058915
# 7      NDWI_LS    0.058295
# 12     S2_NDVI    0.049682
# 3      NDBI_LS    0.032435
# 13     S2_NDWI    0.031232
# 5      NDMI_LS    0.030022
# 25   greenness    0.029458
# 4     NDMI_HLS    0.028689
# 32     wetness    0.027039
# 2     NDBI_HLS    0.026953
# 15    SAVI_HLS    0.025807
# 30       sixth    0.024096
# 6     NDWI_HLS    0.022707
# 24      fourth    0.021789
# 9     S2_MNDWI    0.021454
# 23       fifth    0.014940
# 1     MNDWI_LS    0.014580
# 17        VH_A    0.014162
# 19        VV_A    0.013541
# 18        VH_D    0.013089
# 21  brightness    0.011954
# 22         dem    0.010951
# 26   ndratio_A    0.010521
# 28     ratio_A    0.010464
# 0    MNDWI_HLS    0.008919
# 27   ndratio_D    0.008309
# 20        VV_D    0.008297
# 31       slope    0.007967
# 29     ratio_D    0.007913

# %%
# #shap approach

# best_model = grid_rf.best_estimator_
# explainer = shap.KernelExplainer(best_model.predict, x_train.values)

# ## sample just n num of total data set https://github.com/shap/shap/issues/1197
# shap_values = explainer.shap_values(x_train.values, nsamples=35)  ## currently working but very  very slow
# # shap_values = explainer.shap_values( shap.sample(x_train.values, 35) )

# shap.summary_plot(shap_values, x_train.values, plot_type="bar")
# Out:
# WARNING:shap:Using 3000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/3000 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.828e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.441e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.308e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=1.931e-04, previous alpha=1.523e-04, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.293e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=4.076e-03, previous alpha=4.076e-03, with an active set of 7 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=7.536e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.768e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=2.098e-03, previous alpha=1.836e-03, with an active set of 11 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.185e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 21 iterations, alpha=2.567e-04, previous alpha=2.567e-04, with an active set of 12 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.694e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=1.650e-02, previous alpha=1.599e-02, with an active set of 22 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.419e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 11 iterations, alpha=1.419e-03, previous alpha=1.416e-03, with an active set of 10 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.520e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 20 iterations, alpha=3.796e-03, previous alpha=3.796e-03, with an active set of 9 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.162e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=1.954e-04, previous alpha=1.947e-04, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=8.958e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.557e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=2.057e-02, previous alpha=2.030e-02, with an active set of 20 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=2.317e-05, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=1.242e-05, previous alpha=1.072e-05, with an active set of 19 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=8.459e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 7 iterations, alpha=3.779e-02, previous alpha=3.779e-02, with an active set of 6 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=7.671e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.693e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=2.143e-02, previous alpha=2.120e-02, with an active set of 5 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.842e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 27 iterations, alpha=1.040e-02, previous alpha=1.040e-02, with an active set of 10 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.152e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.705e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.576e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.826e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 13 iterations, alpha=2.767e-03, previous alpha=2.753e-03, with an active set of 10 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=7.434e-05, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.100e-05, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=4.335e-05, previous alpha=2.958e-05, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=3.441e-06, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 22 iterations, alpha=3.441e-06, previous alpha=3.267e-06, with an active set of 17 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=2.957e-04, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.927e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 21 iterations, alpha=2.927e-04, previous alpha=2.896e-04, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.024e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.497e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 28 iterations, alpha=1.750e-03, previous alpha=1.638e-03, with an active set of 19 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.943e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.717e-04, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.418e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.357e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.093e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 13 iterations, alpha=5.240e-04, previous alpha=3.547e-04, with an active set of 12 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.053e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=7.962e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.981e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.973e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.361e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=2.361e-02, previous alpha=2.352e-02, with an active set of 10 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.304e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.684e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 13 iterations, alpha=2.684e-03, previous alpha=2.680e-03, with an active set of 12 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.439e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 21 iterations, alpha=5.810e-04, previous alpha=5.380e-04, with an active set of 18 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=9.541e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.121e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 13 iterations, alpha=3.121e-03, previous alpha=3.109e-03, with an active set of 12 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.316e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=3.515e-03, previous alpha=3.047e-03, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=2.055e-04, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=2.036e-04, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=2.036e-04, previous alpha=1.915e-04, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.018e-05, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.509e-05, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.012e-06, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=4.012e-06, previous alpha=3.442e-06, with an active set of 20 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.321e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=2.245e-03, previous alpha=2.245e-03, with an active set of 18 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.079e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 49 iterations, alpha=9.302e-04, previous alpha=8.832e-04, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.453e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.405e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 14 iterations, alpha=2.580e-03, previous alpha=2.532e-03, with an active set of 11 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.727e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.793e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.853e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 27 iterations, alpha=2.249e-03, previous alpha=1.786e-03, with an active set of 20 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.702e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=1.670e-04, previous alpha=1.670e-04, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.515e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.168e-04, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=1.168e-04, previous alpha=1.162e-04, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.453e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.227e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.141e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=2.184e-02, previous alpha=1.856e-02, with an active set of 9 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=7.544e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.772e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.771e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=3.772e-03, previous alpha=3.761e-03, with an active set of 5 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.208e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=9.749e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.524e-04, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=6.524e-04, previous alpha=6.142e-04, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.765e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 25 iterations, alpha=6.244e-03, previous alpha=6.244e-03, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.524e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=6.363e-03, previous alpha=6.363e-03, with an active set of 9 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.528e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=7.639e-05, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.672e-05, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=3.965e-05, previous alpha=3.920e-05, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.303e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.405e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.371e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 20 iterations, alpha=1.371e-02, previous alpha=1.371e-02, with an active set of 13 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=7.658e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.642e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.292e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 8 iterations, alpha=1.442e-02, previous alpha=1.396e-02, with an active set of 7 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=8.016e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=3.959e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=1.899e-02, previous alpha=1.859e-02, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.394e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.188e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.342e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.710e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=3.565e-04, previous alpha=3.552e-04, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.094e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=8.734e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py:707: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.253e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.134e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=3.299e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=3.134e-03, previous alpha=2.761e-03, with an active set of 18 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=6.596e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.494e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.460e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=8.106e-03, previous alpha=8.043e-03, with an active set of 16 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.891e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.812e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.716e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.716e-03, previous alpha=1.715e-03, with an active set of 11 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.701e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 24 iterations, alpha=8.584e-04, previous alpha=6.054e-04, with an active set of 15 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.814e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.151e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 21 iterations, alpha=1.010e-03, previous alpha=1.003e-03, with an active set of 14 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.546e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.894e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.556e-03, previous alpha=1.187e-03, with an active set of 15 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.050e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=9.262e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.251e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.806e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 8 iterations, alpha=4.220e-02, previous alpha=3.627e-02, with an active set of 7 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.719e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.742e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=4.742e-03, previous alpha=4.741e-03, with an active set of 12 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.940e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 18 iterations, alpha=2.207e-03, previous alpha=2.159e-03, with an active set of 11 regressors.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:725: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.627e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py:755: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=4.402e-03, previous alpha=4.179e-03, with an active set of 6 regressors.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-e93d45966e7a> in <cell line: 12>()
#      10
#      11 ## sample just n num of total data set https://github.com/shap/shap/issues/1197
# ---> 12 shap_values = explainer.shap_values(x_train.values, nsamples=35)  ## currently working but very  very slow
#      13 # shap_values = explainer.shap_values( shap.sample(x_train.values, 35) )
#      14
#
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py in shap_values(self, X, **kwargs)
#     269                 if self.keep_index:
#     270                     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271                 explanations.append(self.explain(data, **kwargs))
#     272                 if kwargs.get("gc_collect", False):
#     273                     gc.collect()
#
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py in explain(self, incoming_instance, **kwargs)
#     480             phi_var = np.zeros((self.data.groups_size, self.D))
#     481             for d in range(self.D):
# --> 482                 vphi, vphi_var = self.solve(self.nsamples / self.max_samples, d)
#     483                 phi[self.varyingInds, d] = vphi
#     484                 phi_var[self.varyingInds, d] = vphi_var
#
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_kernel.py in solve(self, fraction_evaluated, dim)
#     669                     kwg = {}
#     670                 model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC(criterion=c, **kwg))
# --> 671                 nonzero_inds = np.nonzero(model.fit(mask_aug, eyAdj_aug)[1].coef_)[0]
#     672
#     673             # use a fixed regularization coefficient
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     471             if self._final_estimator != "passthrough":
#     472                 last_step_params = routed_params[self.steps[-1][0]]
# --> 473                 self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     474
#     475         return self
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py in fit(self, X, y, copy_X)
#    2249         Gram = self.precompute
#    2250
# -> 2251         alphas_, _, coef_path_, self.n_iter_ = lars_path(
#    2252             X,
#    2253             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     184             global_skip_validation = get_config()["skip_parameter_validation"]
#     185             if global_skip_validation:
# --> 186                 return func(*args, **kwargs)
#     187
#     188             func_sig = signature(func)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py in lars_path(X, y, Xy, Gram, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     216             "Use lars_path_gram to avoid passing X and y."
#     217         )
# --> 218     return _lars_path_solver(
#     219         X=X,
#     220         y=y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_least_angle.py in _lars_path_solver(X, y, Xy, Gram, n_samples, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     806         np.around(corr_eq_dir, decimals=cov_precision, out=corr_eq_dir)
#     807
# --> 808         g1 = arrayfuncs.min_pos((C - Cov) / (AA - corr_eq_dir + tiny32))
#     809         if positive:
#     810             gamma_ = min(g1, C / AA)
#
# ValueError: operands could not be broadcast together with shapes (19,) (18,)

# %% [markdown]
# ## XGBoost Classifer

# %%
param_grid = {'learning_rate' : [0.01], 'n_estimators' : [200], 'random_state': [5],'max_depth' : [9]}

# param_grid = {'learning_rate': [0.005, 0.01, 0.001],
#               'n_estimators': [50,100,200],
#               'random_state': [42],
#               'gamma': [5, 10],
#               'min_child_weight': [5, 10, 15],
#               'max_depth': [5, 10]}

# param_grid = {'learning_rate' : [0.005,0.01,0.001], 'n_estimators' : [40,200], 'random_state': [5],
#               'max_depth' : [4,9]}
grid_xgb = GridSearchCV(XGBClassifier(), param_grid, cv = folds, refit=True, verbose = 0, scoring = score_calc)
grid_xgb.fit(x_train.values, y_train['cropland'].values)

sc_xgb = get_best_score(grid_xgb)
pred_xgb = grid_xgb.predict(x_test.values)
# Out:
# 0.9063333333333332
# {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 200, 'random_state': 5}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=5, ...)

# %%
print('F1-Score:', f1_score(y_test, pred_xgb))
print('Recall:', recall_score(y_test, pred_xgb))
print('Accuracy:',accuracy_score(y_test, pred_xgb))
print('Precision:',precision_score(y_test, pred_xgb))
print('classification_report',classification_report(y_test, pred_xgb))
cm = confusion_matrix(y_test, pred_xgb)
cm
# Out:
# F1-Score: 0.9022704837117473
# Recall: 0.914
# Accuracy: 0.901
# Precision: 0.8908382066276803
# classification_report               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      1500
#            1       0.89      0.91      0.90      1500
#
#     accuracy                           0.90      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.90      0.90      0.90      3000
# array([[1332,  168],
#        [ 129, 1371]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= [0, 1])
disp.plot()

plt.show()

# %%
best_model = grid_xgb.best_estimator_

# Get feature importance from the best model
feature_importance = best_model.feature_importances_

# Create a DataFrame to display feature importance
feature_importance_df = pd.DataFrame({'Feature': x_train.columns.values, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the most important features
print(feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='lightcoral')
plt.gca().invert_yaxis()
plt.xlabel('Importance')
plt.title('Feature Importance from GridSearchCV Optimized XGBoost')
plt.show()
# Out:
#        Feature  Importance
# 16     SAVI_LS    0.245759
# 11     S2_NDMI    0.235763
# 2     NDBI_HLS    0.081778
# 10     S2_NDBI    0.056479
# 14     S2_SAVI    0.043156
# 30       sixth    0.028548
# 4     NDMI_HLS    0.024352
# 19        VV_A    0.022685
# 24      fourth    0.019878
# 25   greenness    0.019744
# 12     S2_NDVI    0.015931
# 17        VH_A    0.015110
# 18        VH_D    0.014284
# 32     wetness    0.013670
# 20        VV_D    0.012989
# 21  brightness    0.012056
# 6     NDWI_HLS    0.011782
# 23       fifth    0.011718
# 1     MNDWI_LS    0.011516
# 27   ndratio_D    0.011000
# 9     S2_MNDWI    0.010876
# 0    MNDWI_HLS    0.010834
# 7      NDWI_LS    0.010702
# 22         dem    0.009747
# 8       S2_EVI    0.009054
# 31       slope    0.008543
# 3      NDBI_LS    0.008504
# 26   ndratio_A    0.008459
# 13     S2_NDWI    0.008005
# 15    SAVI_HLS    0.006440
# 5      NDMI_LS    0.000639
# 28     ratio_A    0.000000
# 29     ratio_D    0.000000

# %% [markdown]
# ## MLP Classifier

# %%
param_grid = {'activation': ['logistic'], 'alpha': [5e-05], 'hidden_layer_sizes': [(50,)], 'learning_rate_init': [0.001],'random_state': [5], 'solver': ['lbfgs']}

# param_grid = {"hidden_layer_sizes": [(1,),(50,)],
#               "activation": ["identity", "logistic", "tanh", "relu"],
#               "solver": ["lbfgs", "sgd", "adam"],
#               "alpha": [0.00005,0.0005],
#               'learning_rate_init': [0.001, 0.01, 0.1, 1],
#               'random_state': [42]}

grid_mlp = GridSearchCV(MLPClassifier(), param_grid, cv = folds, refit=True, verbose = True, scoring = score_calc)
grid_mlp.fit(x_train_norm, y_train['cropland'].values)

sc_mlp = get_best_score(grid_mlp)
pred_mlp = grid_mlp.predict(x_test_norm)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.9096666666666666
# {'activation': 'logistic', 'alpha': 5e-05, 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'random_state': 5, 'solver': 'lbfgs'}
# MLPClassifier(activation='logistic', alpha=5e-05, hidden_layer_sizes=(50,),
#               random_state=5, solver='lbfgs')
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
print('F1-Score:', f1_score(y_test, pred_mlp))
print('Recall:', recall_score(y_test, pred_mlp))
print('Accuracy:',accuracy_score(y_test, pred_mlp))
print('Precision:',precision_score(y_test, pred_mlp))
print('classification_report',classification_report(y_test, pred_mlp))
cm = confusion_matrix(y_test, pred_mlp)
cm
# Out:
# F1-Score: 0.7973368841544607
# Recall: 0.998
# Accuracy: 0.7463333333333333
# Precision: 0.6638580931263858
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.66      1500
#            1       0.66      1.00      0.80      1500
#
#     accuracy                           0.75      3000
#    macro avg       0.83      0.75      0.73      3000
# weighted avg       0.83      0.75      0.73      3000
# array([[ 742,  758],
#        [   3, 1497]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= [0, 1])
disp.plot()

plt.show()

# %%
best_model = grid_mlp.best_estimator_

# Calculate permutation feature importance
perm_importance = permutation_importance(best_model, x_train_norm, y_train['cropland'].values, n_repeats=10, random_state=42)

# Get feature importance into a DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': x_test.columns.values,
    'Importance': perm_importance.importances_mean
})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the most important features
print(feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='coral')
plt.gca().invert_yaxis()
plt.xlabel('Importance')
plt.title('Permutation Feature Importance for MLPClassifier')
plt.show()
# Out:
#        Feature  Importance
# 16     SAVI_LS    0.358267
# 12     S2_NDVI    0.189467
# 10     S2_NDBI    0.058733
# 8       S2_EVI    0.047367
# 21  brightness    0.040367
# 7      NDWI_LS    0.035533
# 9     S2_MNDWI    0.034833
# 5      NDMI_LS    0.032400
# 19        VV_A    0.025467
# 15    SAVI_HLS    0.023300
# 1     MNDWI_LS    0.019200
# 23       fifth    0.018033
# 25   greenness    0.017200
# 32     wetness    0.016833
# 4     NDMI_HLS    0.016300
# 6     NDWI_HLS    0.014500
# 3      NDBI_LS    0.013133
# 13     S2_NDWI    0.013133
# 27   ndratio_D    0.012733
# 20        VV_D    0.010700
# 22         dem    0.009900
# 11     S2_NDMI    0.008300
# 14     S2_SAVI    0.008167
# 30       sixth    0.007200
# 0    MNDWI_HLS    0.006367
# 17        VH_A    0.005300
# 31       slope    0.005233
# 29     ratio_D    0.005033
# 2     NDBI_HLS    0.004133
# 26   ndratio_A    0.003733
# 18        VH_D    0.003067
# 24      fourth    0.002567
# 28     ratio_A    0.000500

# %% [markdown]
# # Cross model comp

# %%
pred_svc
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
list_scores = [sc_svc, sc_rf, sc_xgb, sc_mlp]
list_predictions = [pred_svc, pred_rf, pred_xgb, pred_mlp]
list_regressors = ['SVM','RF','XGB','MLP']
fig, ax = plt.subplots()
fig.set_size_inches(10,7)
sns.barplot(x=list_regressors, y=list_scores, ax=ax)
plt.ylabel('Accuracy Training')
plt.show()

# %%
errors = []
for pred in list_predictions:
    errors.append(accuracy_score(y_test,pred))


regressors = ['SVM','RF','XGB','MLP']
fig, ax = plt.subplots()
fig.set_size_inches(10,7)
sns.barplot(x = regressors, y = errors, ax=ax)
plt.ylabel('Actual Test RMSE')
plt.xlabel('Algorithms')
plt.show()

# %%
predictions = {'SVM': pred_svc,
               'RF': pred_rf,
               'XGB': pred_xgb,
               'MLP':pred_mlp }
df_predictions = pd.DataFrame(data=predictions)

# %%
plt.figure(figsize=(10,8))
cor_pred = df_predictions.corr()
sns.heatmap(cor_pred, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# # Meta Model Approach

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html
#https://github.com/dataprofessor/python/blob/main/Stacking_Classifier.ipynb

estimators =[('svm', grid_svc),
              ('rf', grid_rf),
              ('xgb',grid_xgb),
              ('mlp', grid_mlp)
]


stack_model = StackingClassifier(
    estimators=estimators, final_estimator= RandomForestClassifier(n_estimators=10, random_state=42)
)

# %%
# Train stacked model
stack_model.fit(x_train.values, y_train['cropland'].values)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.773 total time=   0.9s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.740 total time=   0.8s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.760 total time=   0.7s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.5s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.918 total time=   2.0s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.910 total time=   2.0s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.903 total time=   2.2s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.922 total time=   3.2s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.897 total time=   3.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.715 total time=   0.6s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.713 total time=   0.6s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.721 total time=   0.4s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.723 total time=   0.3s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.729 total time=   0.4s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.731 total time=   0.4s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.729 total time=   0.3s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.717 total time=   0.3s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.752 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.4s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.696 total time=   0.3s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.719 total time=   0.3s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.698 total time=   0.3s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.704 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.754 total time=   0.3s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.3s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.3s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.723 total time=   0.3s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.719 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.742 total time=   0.4s
# [CV 2/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.702 total time=   0.3s
# [CV 3/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.762 total time=   0.4s
# [CV 4/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.710 total time=   0.4s
# [CV 5/5] END C=10, coef0=0.01, degree=3, gamma=0.1, kernel=rbf;, score=0.735 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.906 total time=   2.2s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.883 total time=   2.1s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.925 total time=   1.5s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.915 total time=   1.5s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.887 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.910 total time=   1.5s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.910 total time=   1.6s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.917 total time=   2.1s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.908 total time=   2.2s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.898 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.915 total time=   1.5s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.925 total time=   1.6s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.908 total time=   1.6s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.908 total time=   1.6s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.892 total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.919 total time=   1.5s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.927 total time=   1.5s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.890 total time=   1.6s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.900 total time=   1.6s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.902 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.908 total time=   2.0s
# [CV 2/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.923 total time=   2.2s
# [CV 3/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.902 total time=   1.8s
# [CV 4/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.906 total time=   1.5s
# [CV 5/5] END min_samples_split=3, n_estimators=150, random_state=5;, score=0.904 total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# StackingClassifier(estimators=[('svm',
#                                 GridSearchCV(cv=5, estimator=SVC(),
#                                              param_grid={'C': [10],
#                                                          'coef0': [0.01],
#                                                          'degree': [3],
#                                                          'gamma': [0.1],
#                                                          'kernel': ['rbf']},
#                                              scoring='accuracy', verbose=3)),
#                                ('rf',
#                                 GridSearchCV(cv=5,
#                                              estimator=RandomForestClassifier(),
#                                              param_grid={'min_samples_split': [3],
#                                                          'n_estimators': [150],
#                                                          'random_state': [5]},
#                                              scoring='accuracy', verbose=3))...
#                                                          'random_state': [5]},
#                                              scoring='accuracy')),
#                                ('mlp',
#                                 GridSearchCV(cv=5, estimator=MLPClassifier(),
#                                              param_grid={'activation': ['logistic'],
#                                                          'alpha': [5e-05],
#                                                          'hidden_layer_sizes': [(50,)],
#                                                          'learning_rate_init': [0.001],
#                                                          'random_state': [5],
#                                                          'solver': ['lbfgs']},
#                                              scoring='accuracy',
#                                              verbose=True))],
#                    final_estimator=RandomForestClassifier(n_estimators=10,
#                                                           random_state=42))

# %%
stack_model_feat = stack_model.get_feature_names_out()
stack_model_feat
# Out:
# array(['stackingclassifier_svm', 'stackingclassifier_rf',
#        'stackingclassifier_xgb', 'stackingclassifier_mlp'], dtype=object)

# %%
stack_model_params = stack_model.get_params(deep=True)
stack_model_params
# Out:
# {'cv': None,
#  'estimators': [('svm', GridSearchCV(cv=5, estimator=SVC(),
#                 param_grid={'C': [10], 'coef0': [0.01], 'degree': [3],
#                             'gamma': [0.1], 'kernel': ['rbf']},
#                 scoring='accuracy', verbose=3)),
#   ('rf',
#    GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#                 param_grid={'min_samples_split': [3], 'n_estimators': [150],
#                             'random_state': [5]},
#                 scoring='accuracy', verbose=3)),
#   ('xgb',
#    GridSearchCV(cv=5,
#                 estimator=XGBClassifier(base_score=None, booster=None,
#                                         callbacks=None, colsample_bylevel=None,
#                                         colsample_bynode=None,
#                                         colsample_bytree=None, device=None,
#                                         early_stopping_rounds=None,
#                                         enable_categorical=False, eval_metric=None,
#                                         feature_types=None, gamma=None,
#                                         grow_policy=None, importance_type=None,
#                                         interaction_constraints=None,
#                                         learning_rate=None,...
#                                         max_cat_threshold=None,
#                                         max_cat_to_onehot=None,
#                                         max_delta_step=None, max_depth=None,
#                                         max_leaves=None, min_child_weight=None,
#                                         missing=nan, monotone_constraints=None,
#                                         multi_strategy=None, n_estimators=None,
#                                         n_jobs=None, num_parallel_tree=None,
#                                         random_state=None, ...),
#                 param_grid={'learning_rate': [0.01], 'max_depth': [9],
#                             'n_estimators': [200], 'random_state': [5]},
#                 scoring='accuracy')),
#   ('mlp',
#    GridSearchCV(cv=5, estimator=MLPClassifier(),
#                 param_grid={'activation': ['logistic'], 'alpha': [5e-05],
#                             'hidden_layer_sizes': [(50,)],
#                             'learning_rate_init': [0.001], 'random_state': [5],
#                             'solver': ['lbfgs']},
#                 scoring='accuracy', verbose=True))],
#  'final_estimator__bootstrap': True,
#  'final_estimator__ccp_alpha': 0.0,
#  'final_estimator__class_weight': None,
#  'final_estimator__criterion': 'gini',
#  'final_estimator__max_depth': None,
#  'final_estimator__max_features': 'sqrt',
#  'final_estimator__max_leaf_nodes': None,
#  'final_estimator__max_samples': None,
#  'final_estimator__min_impurity_decrease': 0.0,
#  'final_estimator__min_samples_leaf': 1,
#  'final_estimator__min_samples_split': 2,
#  'final_estimator__min_weight_fraction_leaf': 0.0,
#  'final_estimator__monotonic_cst': None,
#  'final_estimator__n_estimators': 10,
#  'final_estimator__n_jobs': None,
#  'final_estimator__oob_score': False,
#  'final_estimator__random_state': 42,
#  'final_estimator__verbose': 0,
#  'final_estimator__warm_start': False,
#  'final_estimator': RandomForestClassifier(n_estimators=10, random_state=42),
#  'n_jobs': None,
#  'passthrough': False,
#  'stack_method': 'auto',
#  'verbose': 0,
#  'svm': GridSearchCV(cv=5, estimator=SVC(),
#               param_grid={'C': [10], 'coef0': [0.01], 'degree': [3],
#                           'gamma': [0.1], 'kernel': ['rbf']},
#               scoring='accuracy', verbose=3),
#  'rf': GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#               param_grid={'min_samples_split': [3], 'n_estimators': [150],
#                           'random_state': [5]},
#               scoring='accuracy', verbose=3),
#  'xgb': GridSearchCV(cv=5,
#               estimator=XGBClassifier(base_score=None, booster=None,
#                                       callbacks=None, colsample_bylevel=None,
#                                       colsample_bynode=None,
#                                       colsample_bytree=None, device=None,
#                                       early_stopping_rounds=None,
#                                       enable_categorical=False, eval_metric=None,
#                                       feature_types=None, gamma=None,
#                                       grow_policy=None, importance_type=None,
#                                       interaction_constraints=None,
#                                       learning_rate=None,...
#                                       max_cat_threshold=None,
#                                       max_cat_to_onehot=None,
#                                       max_delta_step=None, max_depth=None,
#                                       max_leaves=None, min_child_weight=None,
#                                       missing=nan, monotone_constraints=None,
#                                       multi_strategy=None, n_estimators=None,
#                                       n_jobs=None, num_parallel_tree=None,
#                                       random_state=None, ...),
#               param_grid={'learning_rate': [0.01], 'max_depth': [9],
#                           'n_estimators': [200], 'random_state': [5]},
#               scoring='accuracy'),
#  'mlp': GridSearchCV(cv=5, estimator=MLPClassifier(),
#               param_grid={'activation': ['logistic'], 'alpha': [5e-05],
#                           'hidden_layer_sizes': [(50,)],
#                           'learning_rate_init': [0.001], 'random_state': [5],
#                           'solver': ['lbfgs']},
#               scoring='accuracy', verbose=True),
#  'svm__cv': 5,
#  'svm__error_score': nan,
#  'svm__estimator__C': 1.0,
#  'svm__estimator__break_ties': False,
#  'svm__estimator__cache_size': 200,
#  'svm__estimator__class_weight': None,
#  'svm__estimator__coef0': 0.0,
#  'svm__estimator__decision_function_shape': 'ovr',
#  'svm__estimator__degree': 3,
#  'svm__estimator__gamma': 'scale',
#  'svm__estimator__kernel': 'rbf',
#  'svm__estimator__max_iter': -1,
#  'svm__estimator__probability': False,
#  'svm__estimator__random_state': None,
#  'svm__estimator__shrinking': True,
#  'svm__estimator__tol': 0.001,
#  'svm__estimator__verbose': False,
#  'svm__estimator': SVC(),
#  'svm__n_jobs': None,
#  'svm__param_grid': {'C': [10],
#   'coef0': [0.01],
#   'degree': [3],
#   'gamma': [0.1],
#   'kernel': ['rbf']},
#  'svm__pre_dispatch': '2*n_jobs',
#  'svm__refit': True,
#  'svm__return_train_score': False,
#  'svm__scoring': 'accuracy',
#  'svm__verbose': 3,
#  'rf__cv': 5,
#  'rf__error_score': nan,
#  'rf__estimator__bootstrap': True,
#  'rf__estimator__ccp_alpha': 0.0,
#  'rf__estimator__class_weight': None,
#  'rf__estimator__criterion': 'gini',
#  'rf__estimator__max_depth': None,
#  'rf__estimator__max_features': 'sqrt',
#  'rf__estimator__max_leaf_nodes': None,
#  'rf__estimator__max_samples': None,
#  'rf__estimator__min_impurity_decrease': 0.0,
#  'rf__estimator__min_samples_leaf': 1,
#  'rf__estimator__min_samples_split': 2,
#  'rf__estimator__min_weight_fraction_leaf': 0.0,
#  'rf__estimator__monotonic_cst': None,
#  'rf__estimator__n_estimators': 100,
#  'rf__estimator__n_jobs': None,
#  'rf__estimator__oob_score': False,
#  'rf__estimator__random_state': None,
#  'rf__estimator__verbose': 0,
#  'rf__estimator__warm_start': False,
#  'rf__estimator': RandomForestClassifier(),
#  'rf__n_jobs': None,
#  'rf__param_grid': {'min_samples_split': [3],
#   'n_estimators': [150],
#   'random_state': [5]},
#  'rf__pre_dispatch': '2*n_jobs',
#  'rf__refit': True,
#  'rf__return_train_score': False,
#  'rf__scoring': 'accuracy',
#  'rf__verbose': 3,
#  'xgb__cv': 5,
#  'xgb__error_score': nan,
#  'xgb__estimator__objective': 'binary:logistic',
#  'xgb__estimator__base_score': None,
#  'xgb__estimator__booster': None,
#  'xgb__estimator__callbacks': None,
#  'xgb__estimator__colsample_bylevel': None,
#  'xgb__estimator__colsample_bynode': None,
#  'xgb__estimator__colsample_bytree': None,
#  'xgb__estimator__device': None,
#  'xgb__estimator__early_stopping_rounds': None,
#  'xgb__estimator__enable_categorical': False,
#  'xgb__estimator__eval_metric': None,
#  'xgb__estimator__feature_types': None,
#  'xgb__estimator__gamma': None,
#  'xgb__estimator__grow_policy': None,
#  'xgb__estimator__importance_type': None,
#  'xgb__estimator__interaction_constraints': None,
#  'xgb__estimator__learning_rate': None,
#  'xgb__estimator__max_bin': None,
#  'xgb__estimator__max_cat_threshold': None,
#  'xgb__estimator__max_cat_to_onehot': None,
#  'xgb__estimator__max_delta_step': None,
#  'xgb__estimator__max_depth': None,
#  'xgb__estimator__max_leaves': None,
#  'xgb__estimator__min_child_weight': None,
#  'xgb__estimator__missing': nan,
#  'xgb__estimator__monotone_constraints': None,
#  'xgb__estimator__multi_strategy': None,
#  'xgb__estimator__n_estimators': None,
#  'xgb__estimator__n_jobs': None,
#  'xgb__estimator__num_parallel_tree': None,
#  'xgb__estimator__random_state': None,
#  'xgb__estimator__reg_alpha': None,
#  'xgb__estimator__reg_lambda': None,
#  'xgb__estimator__sampling_method': None,
#  'xgb__estimator__scale_pos_weight': None,
#  'xgb__estimator__subsample': None,
#  'xgb__estimator__tree_method': None,
#  'xgb__estimator__validate_parameters': None,
#  'xgb__estimator__verbosity': None,
#  'xgb__estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  'xgb__n_jobs': None,
#  'xgb__param_grid': {'learning_rate': [0.01],
#   'n_estimators': [200],
#   'random_state': [5],
#   'max_depth': [9]},
#  'xgb__pre_dispatch': '2*n_jobs',
#  'xgb__refit': True,
#  'xgb__return_train_score': False,
#  'xgb__scoring': 'accuracy',
#  'xgb__verbose': 0,
#  'mlp__cv': 5,
#  'mlp__error_score': nan,
#  'mlp__estimator__activation': 'relu',
#  'mlp__estimator__alpha': 0.0001,
#  'mlp__estimator__batch_size': 'auto',
#  'mlp__estimator__beta_1': 0.9,
#  'mlp__estimator__beta_2': 0.999,
#  'mlp__estimator__early_stopping': False,
#  'mlp__estimator__epsilon': 1e-08,
#  'mlp__estimator__hidden_layer_sizes': (100,),
#  'mlp__estimator__learning_rate': 'constant',
#  'mlp__estimator__learning_rate_init': 0.001,
#  'mlp__estimator__max_fun': 15000,
#  'mlp__estimator__max_iter': 200,
#  'mlp__estimator__momentum': 0.9,
#  'mlp__estimator__n_iter_no_change': 10,
#  'mlp__estimator__nesterovs_momentum': True,
#  'mlp__estimator__power_t': 0.5,
#  'mlp__estimator__random_state': None,
#  'mlp__estimator__shuffle': True,
#  'mlp__estimator__solver': 'adam',
#  'mlp__estimator__tol': 0.0001,
#  'mlp__estimator__validation_fraction': 0.1,
#  'mlp__estimator__verbose': False,
#  'mlp__estimator__warm_start': False,
#  'mlp__estimator': MLPClassifier(),
#  'mlp__n_jobs': None,
#  'mlp__param_grid': {'activation': ['logistic'],
#   'alpha': [5e-05],
#   'hidden_layer_sizes': [(50,)],
#   'learning_rate_init': [0.001],
#   'random_state': [5],
#   'solver': ['lbfgs']},
#  'mlp__pre_dispatch': '2*n_jobs',
#  'mlp__refit': True,
#  'mlp__return_train_score': False,
#  'mlp__scoring': 'accuracy',
#  'mlp__verbose': True}

# %%
# fn = list(x_train.columns.values)

# fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,12), dpi=800)
# tree.plot_tree(stack_model.estimators_[0],
#                feature_names = fn,
#                class_names=['rh100'],
#                filled = True);
# fig.savefig('stack_model_individualtree.png')

# %%
# sorted_idx = stack_model.feature_importances_.argsort()
# plt.barh(stack_model.feature_importances_[sorted_idx])
# plt.xlabel("stack_model Feature Importance")

# %% [markdown]
# ## Shap viz
#
# https://medium.com/analytics-vidhya/shap-part-2-kernel-shap-3c11e7a971b1

# %%
# ## use the full dataset to viz
# explainer = shap.KernelExplainer(stack_model.predict, x_train.values)
# shap_values = explainer.shap_values(x_train.values)
# shap.summary_plot(shap_values, x_train.values, plot_type="bar")

##
explainer = shap.KernelExplainer(stack_model.predict, x_train.values)


## sample just n num of total data set https://github.com/shap/shap/issues/1197
#shap_values = explainer.shap_values(x_train.values, nsamples=35)  ## currently working but very  very slow
shap_values = explainer.shap_values( shap.sample(x_train.values, 35) )

shap.summary_plot(shap_values, x_train.values, plot_type="bar")

# %%
# Make predictions
y_train_pred_stack = stack_model.predict(x_train.values)
y_test_pred_stack = stack_model.predict(x_test.values)

# %%
# Training set model performance
print('F1-Score:', f1_score(y_train, y_train_pred_stack))
print('Recall:', recall_score(y_train, y_train_pred_stack))
print('Accuracy:',accuracy_score(y_train, y_train_pred_stack))
print('Precision:',precision_score(y_train, y_train_pred_stack))
print('classification_report',classification_report(y_train, y_train_pred_stack))
cm = confusion_matrix(y_train, y_train_pred_stack)
cm
# Out:
# F1-Score: 0.9940119760479041
# Recall: 0.996
# Accuracy: 0.994
# Precision: 0.9920318725099602
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1500
#            1       0.99      1.00      0.99      1500
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.99      0.99      3000
# weighted avg       0.99      0.99      0.99      3000
# array([[1488,   12],
#        [   6, 1494]])

# %%
# Test set model performance
print('F1-Score:', f1_score(y_test,y_test_pred_stack))
print('Recall:', recall_score(y_test,y_test_pred_stack))
print('Accuracy:',accuracy_score(y_test,y_test_pred_stack))
print('Precision:',precision_score(y_test,y_test_pred_stack))
print('classification_report',classification_report(y_test,y_test_pred_stack))
cm = confusion_matrix(y_test,y_test_pred_stack)
cm
# Out:
# F1-Score: 0.8961384820239681
# Recall: 0.8973333333333333
# Accuracy: 0.896
# Precision: 0.8949468085106383
# classification_report               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      1500
#            1       0.89      0.90      0.90      1500
#
#     accuracy                           0.90      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.90      0.90      0.90      3000
# array([[1342,  158],
#        [ 154, 1346]])

# %% [markdown]
# Validation

# %%
y_val_pred_stack = stack_model.predict(x_validation.values)

# %%
# Training set model performance
print('F1-Score:', f1_score(y_validation,y_val_pred_stack))
print('Recall:', recall_score(y_validation,y_val_pred_stack))
print('Accuracy:',accuracy_score(y_validation,y_val_pred_stack))
print('Precision:',precision_score(y_validation,y_val_pred_stack))
print('classification_report',classification_report(y_validation,y_val_pred_stack))
cm = confusion_matrix(y_validation,y_val_pred_stack)
cm
# Out:
# F1-Score: 0.906312292358804
# Recall: 0.9093333333333333
# Accuracy: 0.906
# Precision: 0.9033112582781457
# classification_report               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      1500
#            1       0.90      0.91      0.91      1500
#
#     accuracy                           0.91      3000
#    macro avg       0.91      0.91      0.91      3000
# weighted avg       0.91      0.91      0.91      3000
# array([[1354,  146],
#        [ 136, 1364]])

# %%
# # Initialize base models
# rf = RandomForestRegressor(n_estimators=50, random_state=42)
# knn = KNeighborsRegressor(n_neighbors=5)
# lr = LinearRegression()

# # Fit base models on training data
# rf.fit(x_train, y_train['rh100'])
# knn.fit(x_train, y_train)
# lr.fit(x_train, y_train)

# # Generate base model predictions on training and validation data
# rf_pred_train = rf.predict(x_train)
# knn_pred_train = knn.predict(x_train)
# lr_pred_train = lr.predict(x_train)

# rf_pred_val = rf.predict(x_test)
# knn_pred_val = knn.predict(x_test)
# lr_pred_val = lr.predict(x_test)

# %% [markdown]
# test

# %%
# from sklearn.ensemble import RandomForestRegressor

# %%
# # Combine base model predictions into meta features
# meta_features_train = np.column_stack((rf_pred_train, knn_pred_train, lr_pred_train))
# meta_features_val = np.column_stack((rf_pred_val, knn_pred_val, lr_pred_val))

# # Initialize meta model
# ridge = Ridge(alpha=0.5)

# %%
# # Fit meta model on meta features and training target variable
# ridge.fit(meta_features_train, y_train)

# # Generate meta model predictions on validation set
# meta_pred_val = ridge.predict(meta_features_val)

# from sklearn.metrics import mean_squared_error

# # Calculate MSE on validation set
# mse = mean_squared_error(y_test, meta_pred_val)
# print("MSE on validation set: {:.4f}".format(mse))


# print("MAE train on test",mean_absolute_error(y_test, meta_pred_val))

# print("MSE train on test",mean_squared_error(y_test, meta_pred_val))

# r2 = r2_score(y_test, meta_pred_val)
# print("R2 train on test", r2)

# print("RMSE train on test",np.log(np.sqrt(mean_squared_error(y_test, meta_pred_val))))

# %%
# meta_pred_val

# %%
# rf_test_plot_df = pd.DataFrame({'y_test':y_test['rh100'], 'pred':meta_pred_val})
# # rf_test_plot_df.plot('y_test', 'pred', kind='scatter')

# sns.regplot(data=rf_test_plot_df,x = 'y_test', y = 'meta_pred_val',  ci=99, marker="x", color=".3", line_kws=dict(color="r"))
